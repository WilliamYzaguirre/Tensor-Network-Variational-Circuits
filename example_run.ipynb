# %%
import circuits
import helper_functions
import numpy as np
import matplotlib.pyplot as plt
import qiskit as qsk
# %matplotlib inline
import importlib

# %%
importlib.reload(helper_functions)
importlib.reload(circuits)
helper_functions.run_and_plot(4, 0, 1, "MPS", False, 'swap', 'GHZ_circ', 0.9, None, -1)
# Out:
# Done, final loss: 0.2820996870212411
